# %% [markdown]
# ## **PAIR ASSIGNMENT**
#
# Please work in pairs for this exercise. Pair up with the person next to you. If you find that there isn't anyone sitting next to you or if you're unable to form a pair, please raise your hand, and I will assist in pairing you with someone.
#
#
# ### **Task 0: Please assign your full name and your partner's full name to the variables below, respectively.**
#
#
# Example:
#
# ```
# your_name = 'Taylor Swift'
# your_partner_name = 'Travis Kelce'
# ```

# %%
# Assign your and your partner's names here.  If you find that there isn't anyone sitting next to you or if you're unable to form a pair, please raise your hand.
# If, in the end, we are unable to find a partner for you, please assign the word "self" to the `your_partner_name` variable.
your_name = 'Jonathan Cruz'
your_partner_name = ''

# %% [markdown]
# ## **K-Means Clustering**
#
#
# * In this exercise, you will delve into the world of unsupervised learning by implementing the K-Means clustering algorithm from scratch. For this exercise we will use the classic Iris Dataset.
#
#     * The Iris dataset is a well-known dataset in the field of machine learning and statistics, often used for demonstrating various algorithms. It contains 150 records of Iris flowers from three different species: Iris Setosa, Iris Versicolor, and Iris Virginica. Each record has four features: sepal length, sepal width, petal length, and petal width, all measured in centimeters. The dataset was introduced by the British biologist Ronald Fisher in 1936 as an example of linear discriminant analysis. Its simplicity, clarity, and small size make it ideal for teaching purposes, illustrating the concepts of classification, clustering, and data visualization.
#
#
# * By working with the Iris dataset, you will learn to load and prepare data, initialize centroids randomly, assign data points to the nearest centroids, update centroids based on current assignments, and compute the total variance to evaluate the clustering's effectiveness. This hands-on approach aims to solidify your understanding of the K-Means algorithm's inner workings, including its iterative nature and application in grouping data into meaningful clusters without prior labels. Through these exercises, you will gain practical skills in data manipulation, algorithm implementation, and the critical thinking necessary to apply machine learning algorithms to real-world datasets.

# %%
# Import the libraries

import pandas as pd
import numpy as np

# %% [markdown]
# ### **TASK 1: Load the Dataset**

# %%
def load_dataset():
    """
    Load the dataset from the given path and return it as a NumPy array.

    Parameters:
        path (str): The file path to the dataset.

    Returns:
        numpy.ndarray: The dataset loaded as a NumPy array.
    """
    url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"

    # Column names for the dataset
    column_names = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']

    # Load the dataset
    iris_data = pd.read_csv(url, names=column_names)
    # print(iris_data.dtypes) uncomment this line if you would like to see the results

    # If you uncomment the line above, you will notice that the `species` column is type of "object".
    # K-Means is a method of unsupervised learning that relies on numerical
    # data to compute distances between points and centroids. Since it operates
    # on the principle of minimizing the variance within clusters, the algorithm
    # requires numeric inputs to calculate these distances and variances. If we
    # were using a classification algorithm, species column would be used as our
    # target variable. However, for clustering, we are not looking at variables that
    # could serve as a target variable.
    # For this reason, we will exclude the `species` column from the dataset.
    numeric_iris_data = iris_data.iloc[:, :-1]


    # Convert the DataFrame to a NumPy array and return it
    # write your code here

# %%
load_dataset()

# %% [markdown]
# ## **TASK 2: Initialize Centroids**

# %%
def initialize_centroids(data, k):
    """
    Randomly initialize the centroids for the K-means clustering algorithm.

    Parameters:
        data (numpy.ndarray): The dataset.
        k (int): The number of clusters.

    Returns:
        numpy.ndarray: An array of shape (k, n_features) containing the initial centroids.

    Instructions:
        - Randomly select 'k' data points from the dataset as the initial centroids.
        - For this randomness, you can utilize NumPy's random.permutation() method.
        - Return these centroids as a NumPy array.
    """
    # write your code here
    indices = np.random.permutation(data.shape[0])[:k]
    centroids = data[indices]
    return centroids

# %% [markdown]
# ## **TASK 3: Assign Clusters**
#
#
# * To implement the function below, you will need to calculate the Euclidian distance between points. In the context of clustering:
#     * A "point" refers to a single data point you're comparing to the centroids. "Centroids" are the current centers of the clusters, with each centroid represented as a point in the same multidimensional space.
#     * NumPy supports vectorized operations, allowing you to perform calculations on entire arrays efficiently without writing explicit loops. Use this feature to subtract the point from each centroid, square the differences, sum these squared differences for each point-centroid pair, and then take the square root of these sums.
#
# **Implementation Tips:**
#
# * Start by subtracting the single point from each centroid. Consider the dimensions of your arrays to ensure broadcasting happens correctly.
# * Square the result to eliminate negative values and emphasize larger differences.
# * Sum the squared differences for each centroid to aggregate the component-wise differences into a single value representing the squared Euclidean distance.
# * Finally, take the square root of these sums to obtain the actual distances.
#
#
# The distance between two points \(P\) and \(Q\), with coordinates \(P = (p_1, p_2, ..., p_n)\) and \(Q = (q_1, q_2, ..., q_n)\), is given by:
#
# $$
# d(P, Q) = \sqrt{(p_1 - q_1)^2 + (p_2 - q_2)^2 + ... + (p_n - q_n)^2}
# $$

# %%
def assign_clusters(data, centroids):
    """
    Assign each data point to the nearest centroid.

    Parameters:
        data (numpy.ndarray): The dataset.
        centroids (numpy.ndarray): The current centroids.

    Returns:
        numpy.ndarray: An array of cluster assignments for each data point.

    Instructions:
        - Calculate the Euclidean distance between a single data point and each centroid in a set of centroids.
          The Euclidean distance is the "straight-line" distance between two points in multidimensional space.
        - For each point in the dataset, find the nearest centroid. You can use np.argmin() method to emasure the distances.
        - Return an array containing the index of the nearest centroid for each data point.
    """

    # create an empty list of assignments to append the nearest centroids and convert this list into a
    # numpy array before returning it at the end of this function.

    # iterate ober each point in the dataset

        # calculate the distances

        # find the nearest

        # add to the list

        # return the numpy array from the list
    distances = np.sqrt(((data[:, np.newaxis] - centroids) ** 2).sum(axis=2))
    return np.argmin(distances, axis=1)

# %% [markdown]
# ## **TASK 4: Update Centroids**

# %%
def update_centroids(data, assignments, k):
    """
    Update the centroids based on current cluster assignments.

    Parameters:
        data (numpy.ndarray): The dataset.
        assignments (numpy.ndarray): The current cluster assignments for each data point.
        k (int): The number of clusters.

    Returns:
        numpy.ndarray: An array containing the updated centroids.

    Instructions:
        - For each cluster, calculate the new centroid as the mean of all data points assigned to it.
        - Return the new centroids as a NumPy array.
    """

    # Determine the number of features in the dataset by accessing its shape.


    # Initialize an array to store the new centroids, with dimensions based on the number of clusters and features.

    # Iterate over each cluster index.

    # Select all data points currently assigned to the current cluster.

    # Check if there are any points assigned to the current cluster to avoid division by zero.

    # Calculate the mean (centroid) of all points currently assigned to the current cluster across each feature.

    # Return the array containing the updated centroids.
    n_features = data.shape[1]
    centroids = np.zeros((k, n_features))
    
    for i in range(k):
        points = data[assignments == i]
        
        if len(points) > 0:
            centroids[i] = np.mean(points, axis=0)
    
    return centroids

# %% [markdown]
# ## **TASK 5: Compute Total Variance**

# %%
def compute_total_variance(data, centroids, assignments):
    """
    Compute the total variance, which is the sum of the squared distances between each data point and its assigned centroid.

    Parameters:
        data (numpy.ndarray): The dataset.
        centroids (numpy.ndarray): The centroids.
        assignments (numpy.ndarray): The cluster assignments for each data point.

    Returns:
        float: The total variance of the clustering.

    Instructions:
        - Calculate the squared distance between each data point and its assigned centroid.
        - Sum these distances to get the total variance.
        - Return the total variance as a float.
    """
    total_variance = 0
    # write your code here
    total_variance = 0
    
    for i in range(len(data)):
        centroid = centroids[assignments[i]]
        total_variance += np.sum((data[i] - centroid) ** 2)
    
    return total_variance

# %% [markdown]
# ## **TASK 6: Construct the Main Function**
#
#
# * Follow the steps below to construct the main function that will execute the methods you have implemented above
#
#     * Step 1: Load the Dataset
#         * First, ensure you have correctly implemented a function to load your dataset from the URL specified above
#
#     * Step 2: Choose the Number of Clusters (k)
#         * Decide on the number of clusters, k, you want to identify in your dataset. This choice might be based on prior knowledge about the data or exploratory analysis. For Iris dataset, choosing k=3 is common since there are three species of Iris flowers.
#
#     * Step 3: Initialize Centroids
#         * You'll need the function that randomly initializes the centroids. This step is important for starting the K-Means algorithm.
#
#     * Step 4: Assign Clusters
#         * Call the function to assign each data point to the nearest centroid. This step will form the initial clusters.
#
#     * Step 5: Update Centroids
#         * Call the function that recalculates the centroids based on the current assignments of data points to clusters. This step adjusts the centroids to be the center of the newly formed clusters.
#
#     * Step 6: Compute Total Variance (Optional)
#         * Though not necessary for the basic operation of K-Means, computing the total variance can help in understanding how well the clusters are formed. It measures the compactness of the clusters and can be useful for assessing the algorithm's performance.
#
#     * Step 7: Iterate
#         * The assignment of clusters and updating of centroids should be repeated for a number of iterations or until the centroids no longer change significantly. This iterative process is the core of the K-Means algorithm.

# %%
def main():
    # Load the dataset
    data = load_dataset()

    # Define the number of clusters
    k = 3  # Adjust based on your dataset

    # Initialize centroids


    # Set the number of iterations
    iterations = 10  # You may choose to implement a convergence check instead

    for i in range(iterations):
        # Assign clusters
        assignments = assign_clusters(data, centroids)

        # Update centroids
        centroids = update_centroids(data, assignments, k)

        # (Optional) Compute and print the total variance to monitor improvement
        print(f"Iteration {i+1}, Total Variance: {compute_total_variance(data, centroids, assignments)}")

    print("Final centroids:\n")
    print(centroids)

# %% [markdown]
# ### **Execute your program**

# %%
if __name__ == "__main__":
    main()

# %% [markdown]
# ## **Interpreting the Results Above**
#
# * The "final centroids" represent the central points of the clusters determined by the K-Means algorithm in the feature space of your dataset. Each centroid is a vector of feature values which define the center of a cluster. In the context of the Iris dataset, which has four features (sepal length, sepal width, petal length, and petal width), each centroid is a point in this four-dimensional space.
#
# * Each value in a centroid corresponds to the average value of a specific feature for all the points in that cluster. For example, if a centroid has values (5.0, 3.5, 1.4, 0.2), these represent the average sepal length, sepal width, petal length, and petal width, respectively, of all the flowers in that cluster. The centroid values give insights into the characteristics of the cluster. A centroid with higher values for petal length and petal width, for instance, might represent a group of Iris flowers with larger flowers. By examining the centroids of different clusters, you can compare the clusters' characteristics. Differences in centroid values across clusters highlight how the clusters differ in terms of their feature values.
#
# * Centroids help in understanding the natural segmentation of the data. In the Iris dataset, centroids might help in distinguishing between Iris Setosa, Versicolor, and Virginica based on the natural differences in their flower measurements. Although K-Means is unsupervised and does not use labels during the clustering process, the centroids can be used post-hoc to assign labels to clusters by comparing them with known characteristics of labeled data. For example, if the known average measurements of Iris Setosa closely match a centroid, you might label that cluster as representing Setosa.
